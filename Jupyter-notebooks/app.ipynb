# %%
# !pip install pandas seaborn numpy matplotlib scikit-learn
# Out:
# Requirement already satisfied: pandas in c:\users\thenu\appdata\local\anaconda3\envs\internship\lib\site-packages (2.2.2)
# Requirement already satisfied: seaborn in c:\users\thenu\appdata\local\anaconda3\envs\internship\lib\site-packages (0.13.2)
# Requirement already satisfied: numpy in c:\users\thenu\appdata\local\anaconda3\envs\internship\lib\site-packages (1.26.4)
# Requirement already satisfied: matplotlib in c:\users\thenu\appdata\local\anaconda3\envs\internship\lib\site-packages (3.9.2)
# Requirement already satisfied: scikit-learn in c:\users\thenu\appdata\local\anaconda3\envs\internship\lib\site-packages (1.5.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\thenu\appdata\local\anaconda3\envs\internship\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\thenu\appdata\local\anaconda3\envs\internship\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\thenu\appdata\local\anaconda3\envs\internship\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\thenu\appdata\local\anaconda3\envs\internship\lib\site-packages (from matplotlib) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\thenu\appdata\local\anaconda3\envs\internship\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\thenu\appdata\local\anaconda3\envs\internship\lib\site-packages (from matplotlib) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\thenu\appdata\local\anaconda3\envs\internship\lib\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\thenu\appdata\local\anaconda3\envs\internship\lib\site-packages (from matplotlib) (24.1)
# Requirement already satisfied: pillow>=8 in c:\users\thenu\appdata\local\anaconda3\envs\internship\lib\site-packages (from matplotlib) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\thenu\appdata\local\anaconda3\envs\internship\lib\site-packages (from matplotlib) (3.1.2)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\thenu\appdata\local\anaconda3\envs\internship\lib\site-packages (from scikit-learn) (1.13.1)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\thenu\appdata\local\anaconda3\envs\internship\lib\site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\thenu\appdata\local\anaconda3\envs\internship\lib\site-packages (from scikit-learn) (3.5.0)
# Requirement already satisfied: six>=1.5 in c:\users\thenu\appdata\local\anaconda3\envs\internship\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
data=pd.read_csv('../datasets/heart.csv')

# %%
data.head(20)
# Out:
#     Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 0    40   M           ATA        140          289          0     Normal
# 1    49   F           NAP        160          180          0     Normal
# 2    37   M           ATA        130          283          0         ST
# 3    48   F           ASY        138          214          0     Normal
# 4    54   M           NAP        150          195          0     Normal
# 5    39   M           NAP        120          339          0     Normal
# 6    45   F           ATA        130          237          0     Normal
# 7    54   M           ATA        110          208          0     Normal
# 8    37   M           ASY        140          207          0     Normal
# 9    48   F           ATA        120          284          0     Normal
# 10   37   F           NAP        130          211          0     Normal
# 11   58   M           ATA        136          164          0         ST
# 12   39   M           ATA        120          204          0     Normal
# 13   49   M           ASY        140          234          0     Normal
# 14   42   F           NAP        115          211          0         ST
# 15   54   F           ATA        120          273          0     Normal
# 16   38   M           ASY        110          196          0     Normal
# 17   43   F           ATA        120          201          0     Normal
# 18   60   M           ASY        100          248          0     Normal
# 19   36   M           ATA        120          267          0     Normal
#
#     MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0     172              N      0.0       Up             0
# 1     156              N      1.0     Flat             1
# 2      98              N      0.0       Up             0
# 3     108              Y      1.5     Flat             1
# 4     122              N      0.0       Up             0
# 5     170              N      0.0       Up             0
# 6     170              N      0.0       Up             0
# 7     142              N      0.0       Up             0
# 8     130              Y      1.5     Flat             1
# 9     120              N      0.0       Up             0
# 10    142              N      0.0       Up             0
# 11     99              Y      2.0     Flat             1
# 12    145              N      0.0       Up             0
# 13    140              Y      1.0     Flat             1
# 14    137              N      0.0       Up             0
# 15    150              N      1.5     Flat             0
# 16    166              N      0.0     Flat             1
# 17    165              N      0.0       Up             0
# 18    125              N      1.0     Flat             1
# 19    160              N      3.0     Flat             1

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 918 entries, 0 to 917
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Age             918 non-null    int64
#  1   Sex             918 non-null    object
#  2   ChestPainType   918 non-null    object
#  3   RestingBP       918 non-null    int64
#  4   Cholesterol     918 non-null    int64
#  5   FastingBS       918 non-null    int64
#  6   RestingECG      918 non-null    object
#  7   MaxHR           918 non-null    int64
#  8   ExerciseAngina  918 non-null    object
#  9   Oldpeak         918 non-null    float64
#  10  ST_Slope        918 non-null    object
#  11  HeartDisease    918 non-null    int64
# dtypes: float64(1), int64(6), object(5)
# memory usage: 86.2+ KB

# %%
data.describe()
# Out:
#               Age   RestingBP  Cholesterol   FastingBS       MaxHR  \
# count  918.000000  918.000000   918.000000  918.000000  918.000000
# mean    53.510893  132.396514   198.799564    0.233115  136.809368
# std      9.432617   18.514154   109.384145    0.423046   25.460334
# min     28.000000    0.000000     0.000000    0.000000   60.000000
# 25%     47.000000  120.000000   173.250000    0.000000  120.000000
# 50%     54.000000  130.000000   223.000000    0.000000  138.000000
# 75%     60.000000  140.000000   267.000000    0.000000  156.000000
# max     77.000000  200.000000   603.000000    1.000000  202.000000
#
#           Oldpeak  HeartDisease
# count  918.000000    918.000000
# mean     0.887364      0.553377
# std      1.066570      0.497414
# min     -2.600000      0.000000
# 25%      0.000000      0.000000
# 50%      0.600000      1.000000
# 75%      1.500000      1.000000
# max      6.200000      1.000000

# %%
data.shape
# Out:
# (918, 12)

# %%
data.dtypes
# Out:
# Age                 int64
# Sex                object
# ChestPainType      object
# RestingBP           int64
# Cholesterol         int64
# FastingBS           int64
# RestingECG         object
# MaxHR               int64
# ExerciseAngina     object
# Oldpeak           float64
# ST_Slope           object
# HeartDisease        int64
# dtype: object

# %%
from sklearn.model_selection import train_test_split
train ,test= train_test_split(data, test_size=0.20)

# %%
train[["Age", "RestingBP", "Cholesterol", "MaxHR", "Oldpeak"]]
# Out:
#      Age  RestingBP  Cholesterol  MaxHR  Oldpeak
# 600   57        130          207     96      1.0
# 916   57        130          236    174      0.0
# 900   58        114          318    140      4.4
# 225   50        145          264    150      0.0
# 128   54        120          230    140      0.0
# ..   ...        ...          ...    ...      ...
# 2     37        130          283     98      0.0
# 68    52        160          246     82      4.0
# 624   63        150          407    154      4.0
# 594   58        160          256    113      1.0
# 569   55        158          217    110      2.5
#
# [734 rows x 5 columns]

# %%
train_data_num = train [["Age", "RestingBP", "Cholesterol", "MaxHR", "Oldpeak"]]
for i in ["Age", "RestingBP", "Cholesterol", "MaxHR", "Oldpeak"]:
    plt.hist(train_data_num[i])
    plt.title(i)
    plt.show()
    plt.boxplot(train_data_num[i])
    plt.title(i)
    plt.show()

# %%
sns.heatmap(train_data_num.corr())
# Out:
# <Axes: >

# %%
pd.pivot_table(train,index="HeartDisease", values=["Age","RestingBP", "Cholesterol", "FastingBS", "MaxHR", "Oldpeak"])
# Out:
#                     Age  Cholesterol  FastingBS       MaxHR   Oldpeak  \
# HeartDisease
# 0             50.292169   226.307229   0.093373  147.885542  0.436747
# 1             55.803483   174.325871   0.333333  127.181592  1.256716
#
#                RestingBP
# HeartDisease
# 0             129.942771
# 1             133.930348

# %%
train_data_quali = train[['Sex','ChestPainType', 'FastingBS', 'RestingECG', 'ExerciseAngina', 'ST_Slope']]

for info in train_data_quali.columns:
  sns.barplot(x=train_data_quali[info].value_counts().index, y=train_data_quali[info].value_counts()).set_title(info)
  plt.show()

# %%
train=pd.get_dummies(train)
test = pd.get_dummies(test)

train.head(20)
# Out:
#      Age  RestingBP  Cholesterol  FastingBS  MaxHR  Oldpeak  HeartDisease  \
# 600   57        130          207          0     96      1.0             0
# 916   57        130          236          0    174      0.0             1
# 900   58        114          318          0    140      4.4             1
# 225   50        145          264          0    150      0.0             1
# 128   54        120          230          1    140      0.0             0
# 803   62        140          394          0    157      1.2             0
# 423   60        180            0          0    140      1.5             0
# 737   57        152          274          0     88      1.2             1
# 144   56        120          279          0    150      1.0             1
# 195   62        160          193          0    116      0.0             0
# 549   68        139          181          1    135      0.2             0
# 129   42        120          228          0    152      1.5             0
# 873   64        140          335          0    158      0.0             1
# 82    63        150          223          0    115      0.0             1
# 649   50        144          200          0    126      0.9             1
# 438   63        130            0          0    111      0.0             1
# 766   50        120          219          0    158      1.6             0
# 504   62        158          210          1    112      3.0             1
# 132   56        170          388          0    122      2.0             1
# 321   63        100            0          1    109     -0.9             1
#
#      Sex_F  Sex_M  ChestPainType_ASY  ...  ChestPainType_NAP  \
# 600  False   True               True  ...              False
# 916   True  False              False  ...              False
# 900  False   True               True  ...              False
# 225  False   True               True  ...              False
# 128   True  False              False  ...              False
# 803   True  False               True  ...              False
# 423  False   True              False  ...               True
# 737  False   True               True  ...              False
# 144   True  False              False  ...              False
# 195   True  False              False  ...              False
# 549  False   True              False  ...              False
# 129  False   True              False  ...               True
# 873  False   True              False  ...               True
# 82   False   True               True  ...              False
# 649  False   True               True  ...              False
# 438  False   True              False  ...               True
# 766   True  False              False  ...               True
# 504  False   True               True  ...              False
# 132  False   True               True  ...              False
# 321  False   True               True  ...              False
#
#      ChestPainType_TA  RestingECG_LVH  RestingECG_Normal  RestingECG_ST  \
# 600             False           False              False           True
# 916             False            True              False          False
# 900             False           False              False           True
# 225             False           False               True          False
# 128             False           False               True          False
# 803             False            True              False          False
# 423             False           False              False           True
# 737             False           False               True          False
# 144             False           False               True          False
# 195              True           False               True          False
# 549              True           False              False           True
# 129             False           False               True          False
# 873             False           False               True          False
# 82              False           False               True          False
# 649             False            True              False          False
# 438             False           False              False           True
# 766             False           False               True          False
# 504             False           False               True          False
# 132             False           False              False           True
# 321             False           False               True          False
#
#      ExerciseAngina_N  ExerciseAngina_Y  ST_Slope_Down  ST_Slope_Flat  \
# 600             False              True          False           True
# 916              True             False          False           True
# 900              True             False           True          False
# 225              True             False          False           True
# 128              True             False          False          False
# 803              True             False          False           True
# 423             False              True          False           True
# 737             False              True          False           True
# 144              True             False          False           True
# 195              True             False          False          False
# 549              True             False          False          False
# 129             False              True          False           True
# 873              True             False          False          False
# 82               True             False          False           True
# 649             False              True          False           True
# 438             False              True          False           True
# 766              True             False          False           True
# 504             False              True           True          False
# 132             False              True          False           True
# 321              True             False          False           True
#
#      ST_Slope_Up
# 600        False
# 916        False
# 900        False
# 225        False
# 128         True
# 803        False
# 423        False
# 737        False
# 144        False
# 195         True
# 549         True
# 129        False
# 873         True
# 82         False
# 649        False
# 438        False
# 766        False
# 504        False
# 132        False
# 321        False
#
# [20 rows x 21 columns]

# %%
x_train = train.drop(columns = ["HeartDisease"])
y_train = train["HeartDisease"]

x_test = test.drop(columns = ["HeartDisease"])
y_test = test["HeartDisease"]

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix 
from sklearn.metrics import accuracy_score 
from sklearn.metrics import classification_report

# %%
model=LogisticRegression()
model=model.fit(x_train, y_train)
predicted=model.predict(x_test)
# Out:
# c:\Users\Thenu\AppData\Local\anaconda3\envs\internship\Lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
results = confusion_matrix(y_test, predicted) 

print ('Confusion Matrix :')
print(results) 
print ('Accuracy Score :',accuracy_score(y_test, predicted) )
print ('Report : ')
print( classification_report(y_test, predicted) )
# Out:
# Confusion Matrix :
# [[65 13]
#  [10 96]]
# Accuracy Score : 0.875
# Report :
#               precision    recall  f1-score   support
#
#            0       0.87      0.83      0.85        78
#            1       0.88      0.91      0.89       106
#
#     accuracy                           0.88       184
#    macro avg       0.87      0.87      0.87       184
# weighted avg       0.87      0.88      0.87       184

# %%
def sur(model, Age=25, RestingBP=140, Cholesterol=150, FastingBS=0, MaxHR=120, Oldpeak=0.5, HeartDisease=0, Sex_F=True, Sex_M=False, ChestPainType_ASY=False, ChestPainType_NAP=False, ChestPainType_TA=False, RestingECG_LVH=True, RestingECG_Normal=False, RestingECG_ST=False, ExerciseAngina_N=True, ExerciseAngina_Y=False, ST_Slope_Down=True, ST_Slope_Flat=True, ST_Slope_Up=False):
    x = np.array([ Age, RestingBP, Cholesterol, FastingBS, MaxHR, Oldpeak, HeartDisease, Sex_F, Sex_M, ChestPainType_ASY, ChestPainType_NAP, ChestPainType_TA, RestingECG_LVH, RestingECG_Normal, RestingECG_ST, ExerciseAngina_N, ExerciseAngina_Y, ST_Slope_Down, ST_Slope_Flat, ST_Slope_Up]).reshape(1, 20)
    print(model.predict(x))
    print(model.predict_proba(x))

# %%
sur(model=model)
# Out:
# [1]
# [[0.32636747 0.67363253]]
# c:\Users\Thenu\AppData\Local\anaconda3\envs\internship\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# c:\Users\Thenu\AppData\Local\anaconda3\envs\internship\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
